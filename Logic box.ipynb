# %%
print("Welcome to the Pattern Generator and Number Analyzer!")

while True:
    print("Select an option: ")
    print("1.Generate a Pattern")
    print("2.Analyze a Range of number")
    print("3.Exit")

    a = int(input("Enter your choice: "))
    if a == 1:
        n = int(input("Enter the number of rows for the pattern: "))
        print("Pattern:")
        for i in range(1, n + 1):
            print(' ' * (n-i)+ '*' * (2*i-1))

    elif a == 2:
        start = int(input("Enter the start of the range: "))
        end = int(input("Enter the end of the range: "))
        for num in range(start, end +1):
            if num % 2 == 0:
                print("Number",num,"is Even")
            else:
                print("Number",num,"is Odd")
        total = sum(range(start, end + 1))
        print("sum of number from",start,"to",end,":" ,total)

    elif a == 3:
        print("Thank you for using this program,..GOODBYE....")
        break

    else:
        print("Invalid choice")
# Out:
# Welcome to the Pattern Generator and Number Analyzer!
# Select an option:
# 1.Generate a Pattern
# 2.Analyze a Range of number
# 3.Exit
# Enter your choice:  1
# Enter the number of rows for the pattern:  8
# Pattern:
#        *
#       ***
#      *****
#     *******
#    *********
#   ***********
#  *************
# ***************
# Select an option:
# 1.Generate a Pattern
# 2.Analyze a Range of number
# 3.Exit
# Enter your choice:  2
# Enter the start of the range:  17
# Enter the end of the range:  29
# Number 17 is Odd
# Number 18 is Even
# Number 19 is Odd
# Number 20 is Even
# Number 21 is Odd
# Number 22 is Even
# Number 23 is Odd
# Number 24 is Even
# Number 25 is Odd
# Number 26 is Even
# Number 27 is Odd
# Number 28 is Even
# Number 29 is Odd
# sum of number from 17 to 29 : 299
# Select an option:
# 1.Generate a Pattern
# 2.Analyze a Range of number
# 3.Exit
# Enter your choice:  3
# Thank you for using this program,..GOODBYE....
